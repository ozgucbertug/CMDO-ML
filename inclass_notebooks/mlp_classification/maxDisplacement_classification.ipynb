# %% [markdown]
# # MLP Classification on the Max Displacement Dataset
#
# This notebook is written as a guided walkthrough for first-time learners, using `inclass_notebooks/data/param_disp_dataset.csv` to solve a binary classification task. You will convert a continuous structural response (`max_disp`) into a class label with a configurable threshold, then train a baseline classifier and a small MLP and compare how they behave. The goal is not only to run code, but to build an interpretation habit: each section explains what a result means and how you should read it before moving forward.
#
# Learning goals are embedded directly in the flow: by the end, you should be able to inspect tabular data quality, derive a valid target column, reason about class balance, run PCA and t-SNE for geometric intuition, split data without leakage, standardize features correctly, train classification models with early stopping, and interpret confusion matrices, ROC curves, and class-wise metrics in plain language.

# %% [markdown]
# ## 1. Imports + Reproducibility Seed
#
# Before touching the dataset, we set up the environment so your notebook behaves predictably. Reproducibility is especially important in machine learning because optimization and sampling procedures can introduce randomness. If you were to run the same notebook with different random seeds, likely you'll get slightly different metrics, and this can often be misinterpreted as a coding error. Setting a fixed seed does not make a model “perfectly deterministic” in every hardware setup, but it greatly improves stability for comparison.
#
# You will also import the exact toolchain used in this notebook: `pandas` for tabular data, `scikit-learn` for preprocessing and evaluation utilities, `matplotlib/seaborn` for visualization, and `keras` for the neural network model.

# %%
from pathlib import Path
import random
import warnings

warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    ConfusionMatrixDisplay,
    RocCurveDisplay,
    roc_auc_score,
)

import tensorflow as tf
from tensorflow import keras

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

sns.set_theme(style="whitegrid")
print(f"Seed fixed to {SEED} for Python, NumPy, and TensorFlow.")
# Out:
# Seed fixed to 42 for Python, NumPy, and TensorFlow.

# %% [markdown]
# ## 2. Load Dataset + Define the Classification Target
#
# The raw CSV stores `max_disp` as a continuous value. For classification, we need discrete labels, so we define a threshold rule as:
#
# `target_class = max_disp > THRESHOLD`
#
# The threshold is intentionally a variable so you can experiment later. A threshold near the center of the target distribution typically gives balanced classes, while extreme thresholds can create severe class imbalance. That imbalance affects how useful metrics like accuracy are, so we will always inspect class counts right after target construction.
#
# This cell also performs a practical path check so the notebook works whether your kernel starts from the repo root or from the notebook directory.

# %%
THRESHOLD = 10.0

candidate_paths = [
    Path("../data/param_disp_dataset.csv"),                # if cwd is inclass_notebooks/01_mlp_classification/
    Path("inclass_notebooks/data/param_disp_dataset.csv"), # if cwd is repo root
]
CSV_PATH = next((p for p in candidate_paths if p.exists()), None)

if CSV_PATH is None:
    raise FileNotFoundError(
        "Could not find param_disp_dataset.csv. Expected it at '../data/' from this notebook folder "
        "or at 'inclass_notebooks/data/' from repo root."
    )

df = pd.read_csv(CSV_PATH)
target_col = "max_disp"

if target_col not in df.columns:
    raise ValueError("The dataset must contain a 'max_disp' column.")

feature_cols = [c for c in df.columns if c.startswith("x_")]
if not feature_cols:
    raise ValueError("No feature columns found. Expected columns named like x_0, x_1, ..., x_27.")

df["target_class"] = (df[target_col] > THRESHOLD).astype(int)
X = df[feature_cols].copy()
y = df["target_class"].copy()

print(f"Loaded file: {CSV_PATH.resolve()}")
print(f"Rows: {len(df):,} | Feature columns: {len(feature_cols)}")
print(f"Classification threshold: max_disp > {THRESHOLD}")
print("Class counts (0 = at/below threshold, 1 = above threshold):")
print(y.value_counts())
print("First 5 rows:")
display(df.head())
# Out:
# Loaded file: /Users/ozgucbertugcapunaman/Documents/GitHub/CMDO-ML/inclass_notebooks/data/param_disp_dataset.csv
# Rows: 10,000 | Feature columns: 28
# Classification threshold: max_disp > 10.0
# Class counts (0 = at/below threshold, 1 = above threshold):
# target_class
# 0    5186
# 1    4814
# Name: count, dtype: int64
# First 5 rows:
#    index       x_0       x_1      x_10      x_11      x_12      x_13  \
# 0      0  0.139427 -0.474989 -0.281362  0.005355 -0.473464 -0.301162
# 1      1  0.347494  0.103726  0.361707  0.077352  0.204572 -0.454176
# 2      2 -0.328861  0.229127 -0.270952 -0.467900 -0.184547 -0.232259
# 3      3 -0.100599 -0.280679 -0.436472 -0.118381  0.496121  0.029114
# 4      4  0.000586 -0.321348  0.278626  0.030354 -0.499428 -0.175844
#
#        x_14      x_15      x_16  ...      x_27       x_3       x_4       x_5  \
# 0  0.149884  0.044941 -0.279559  ... -0.403284 -0.276789  0.236471  0.176699
# 1 -0.272102 -0.210612 -0.420208  ...  0.109131  0.229732  0.036228  0.473116
# 2 -0.289017  0.442910  0.376368  ...  0.397823 -0.120545  0.489523  0.140000
# 3  0.471078  0.360780 -0.488519  ... -0.236611  0.009526 -0.409091 -0.452884
# 4 -0.480523  0.429099  0.378722  ... -0.371609  0.370519 -0.201555  0.138949
#
#         x_6       x_7       x_8       x_9   max_disp  target_class
# 0  0.392180 -0.413061 -0.078078 -0.470203  12.004013             1
# 1 -0.121466  0.052041  0.329405  0.118520   2.692905             0
# 2  0.056950  0.184614  0.342852  0.276000   7.544037             0
# 3 -0.390351  0.127446  0.292079 -0.077840  13.496088             1
# 4  0.108970 -0.347161  0.262511  0.039379   8.338048             0
#
# [5 rows x 31 columns]

# %% [markdown]
# ## 3. Data Quality Check
#
# A fast quality check prevents subtle failures later in the pipeline. Here we verify missing values, duplicate rows, and label consistency. In beginner workflows, skipping this stage is a common source of confusion because model performance issues can come from data defects rather than model design.
#
# When you read this output, focus on three questions. First, are there missing values that could break model fitting? Second, are there duplicate rows that might overstate performance? Third, is the class ratio reasonable for the metrics you intend to use? If one class is very rare, accuracy alone is not a trustworthy summary.

# %%
missing_counts = df.isna().sum()
missing_total = int(missing_counts.sum())
duplicate_rows = int(df.duplicated().sum())
class_ratio = y.value_counts(normalize=True).sort_index()

print(f"Total missing values across all columns: {missing_total}")
if missing_total > 0:
    display(missing_counts[missing_counts > 0].to_frame("missing_count"))
else:
    print("No missing values detected.")

print(f"Duplicate rows: {duplicate_rows}")
print()
print("Class proportion (0, 1):")
print((class_ratio * 100).round(2).astype(str) + "%")
# Out:
# Total missing values across all columns: 0
# No missing values detected.
# Duplicate rows: 0
#
# Class proportion (0, 1):
# target_class
# 0    51.86%
# 1    48.14%
# Name: proportion, dtype: str

# %% [markdown]
# ## 4. Exploratory Data Analysis (EDA)
#
# In this step you build intuition before training anything. Start with the raw target distribution (`max_disp`) and verify where your threshold sits.
#
# You should not expect one plot to “prove” model quality. Instead, treat EDA as a map: where is the target concentrated and how balanced are classes.

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 4.5))

sns.histplot(df["max_disp"], bins=45, kde=True, color="#2a9d8f", ax=axes[0])
axes[0].axvline(THRESHOLD, color="#e76f51", linestyle="--", linewidth=2, label=f"Threshold = {THRESHOLD}")
axes[0].set_title("Distribution of max_disp")
axes[0].set_xlabel("max_disp")
axes[0].legend()

sns.countplot(x=y, palette=["#264653", "#f4a261"], ax=axes[1])
axes[1].set_title("Derived Class Balance")
axes[1].set_xlabel("target_class")
axes[1].set_ylabel("count")

plt.tight_layout()
plt.show()

corr_with_target = (
    df[feature_cols + ["max_disp"]]
    .corr(numeric_only=True)["max_disp"]
    .drop("max_disp")
    .sort_values(key=np.abs, ascending=False)
)

# %% [markdown]
# ### PCA + t-SNE Projection (Structure in Feature Space)
#
# Now you project the 28-dimensional feature space into 2 dimensions with two different methods. PCA is linear and tells you how much variance each principal axis captures. t-SNE is nonlinear and focuses on local neighborhoods, often revealing clusters that PCA can miss. These methods are for understanding geometry, not for direct performance measurement.
#
# For PCA, read the explained variance ratio as “how much of total feature variation this axis summarizes.” For example, if PC1 is 0.20, then PC1 alone captures 20% of variation. If PC1+PC2 is 0.35, then your 2D PCA view preserves about 35% of the original variability. Loadings tell you which original features contribute most strongly to each principal component direction.
#
# For t-SNE, avoid over-interpreting global distances. Separation in t-SNE can be informative, but axis values themselves have no direct physical meaning. To keep runtime demo-friendly, we subsample before t-SNE.
#
# References for deeper reading: [scikit-learn PCA User Guide](https://scikit-learn.org/stable/modules/decomposition.html#pca), [scikit-learn t-SNE User Guide](https://scikit-learn.org/stable/modules/manifold.html#t-sne), [Distill: How to Use t-SNE Effectively](https://distill.pub/2016/misread-tsne/).

# %%
# Standardize only for visualization geometry; this is not the training scaler yet.
X_scaled_for_eda = StandardScaler().fit_transform(X)

# ----- PCA -----
pca = PCA(n_components=2, random_state=SEED)
X_pca = pca.fit_transform(X_scaled_for_eda)

evr = pca.explained_variance_ratio_
print(f"PCA explained variance ratio -> PC1: {evr[0]:.4f}, PC2: {evr[1]:.4f}")
print(f"PCA cumulative explained variance (PC1 + PC2): {evr.sum():.4f}")

# ----- t-SNE (sampled for speed) -----
tsne_sample_size = min(1200, len(X_scaled_for_eda))
rng = np.random.default_rng(SEED)
sample_idx = rng.choice(len(X_scaled_for_eda), size=tsne_sample_size, replace=False)
X_tsne_input = X_scaled_for_eda[sample_idx]
y_tsne = y.iloc[sample_idx].reset_index(drop=True)

X_tsne = TSNE(
    n_components=2,
    perplexity=30,
    learning_rate="auto",
    init="pca",
    random_state=SEED,
).fit_transform(X_tsne_input)

fig, axes = plt.subplots(1, 2, figsize=(14, 5.5))

sns.scatterplot(
    x=X_pca[:, 0],
    y=X_pca[:, 1],
    hue=y.astype(str),
    palette="Set1",
    s=28,
    alpha=0.85,
    ax=axes[0],
)
axes[0].set_title("PCA projection (all samples)")
axes[0].set_xlabel("PC1")
axes[0].set_ylabel("PC2")
axes[0].legend(title="target_class")

sns.scatterplot(
    x=X_tsne[:, 0],
    y=X_tsne[:, 1],
    hue=y_tsne.astype(str),
    palette="Set2",
    s=32,
    alpha=0.9,
    ax=axes[1],
)
axes[1].set_title(f"t-SNE projection (sample = {tsne_sample_size})")
axes[1].set_xlabel("t-SNE 1")
axes[1].set_ylabel("t-SNE 2")
axes[1].legend(title="target_class")

plt.tight_layout()
plt.show()
# Out:
# PCA explained variance ratio -> PC1: 0.0392, PC2: 0.0388
# PCA cumulative explained variance (PC1 + PC2): 0.0780

# %% [markdown]
# ## 5. Train/Validation/Test Split
#
# We split first, before fitting any preprocessing transforms, so the validation and test sets stay truly unseen. This is the foundation of honest evaluation. In classification, you should usually stratify so each split keeps roughly the same class ratio; otherwise, a random split can accidentally distort class balance and make metrics unstable.
#
# The two-step split below gives approximately 70% train, 15% validation, and 15% test. Validation is used during model development (for early stopping and model choices), while test is reserved for the final one-time performance estimate.
#
# References for stronger foundations: [scikit-learn: train_test_split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html), [scikit-learn: StandardScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html), [Data leakage overview (scikit-learn common pitfalls)](https://scikit-learn.org/stable/common_pitfalls.html#data-leakage).

# %%
X_train_raw, X_temp_raw, y_train, y_temp = train_test_split(
    X,
    y,
    test_size=0.30,
    random_state=SEED,
    stratify=y,
)

X_val_raw, X_test_raw, y_val, y_test = train_test_split(
    X_temp_raw,
    y_temp,
    test_size=0.50,
    random_state=SEED,
    stratify=y_temp,
)

print("Split sizes:")
print(f"Train: {X_train_raw.shape[0]} samples")
print(f"Val:   {X_val_raw.shape[0]} samples")
print(f"Test:  {X_test_raw.shape[0]} samples")

print()
print("Class balance check (proportion of class 1):")
print(f"Train: {y_train.mean():.3f}")
print(f"Val:   {y_val.mean():.3f}")
print(f"Test:  {y_test.mean():.3f}")
# Out:
# Split sizes:
# Train: 7000 samples
# Val:   1500 samples
# Test:  1500 samples
#
# Class balance check (proportion of class 1):
# Train: 0.481
# Val:   0.481
# Test:  0.481

# %% [markdown]
# ## 6. Leakage-Safe Preprocessing (Standardization)
#
# Neural networks and linear models train more reliably when feature scales are comparable. Standardization rescales each feature to zero mean and unit variance, but this transform must be fitted on training data only. If you fit the scaler on all data, information from validation/test leaks into training and inflates performance estimates.
#
# Read the quick diagnostics at the end of this cell as a sanity check. You should see train-set scaled means close to 0 and standard deviations close to 1 for each feature.

# %%
scaler = StandardScaler()

# Fit only on training inputs to avoid leakage.
X_train = scaler.fit_transform(X_train_raw)
X_val = scaler.transform(X_val_raw)
X_test = scaler.transform(X_test_raw)

print("Scaled arrays ready.")
print("Train scaled mean (first 5 features):", np.round(X_train.mean(axis=0)[:5], 3))
print("Train scaled std  (first 5 features):", np.round(X_train.std(axis=0)[:5], 3))
# Out:
# Scaled arrays ready.
# Train scaled mean (first 5 features): [0. 0. 0. 0. 0.]
# Train scaled std  (first 5 features): [1. 1. 1. 1. 1.]

# %% [markdown]
# ## 7. Baseline Model (Logistic Regression)
#
# A baseline answers one critical question: is the neural network actually adding value? Logistic regression is a strong, interpretable baseline for binary classification on tabular data. If your MLP barely beats it, your dataset might be close to linearly separable or your neural network setup may need adjustment.
#
# Use the validation split here because we are still in development mode. Test data remains untouched until the final evaluation section.

# %%
baseline = LogisticRegression(max_iter=1000, random_state=SEED)
baseline.fit(X_train, y_train)

baseline_val_pred = baseline.predict(X_val)

print("Validation metrics - Logistic Regression baseline")
print(f"Accuracy : {accuracy_score(y_val, baseline_val_pred):.4f}")
print(f"Precision: {precision_score(y_val, baseline_val_pred):.4f}")
print(f"Recall   : {recall_score(y_val, baseline_val_pred):.4f}")
print(f"F1-score : {f1_score(y_val, baseline_val_pred):.4f}")
# Out:
# Validation metrics - Logistic Regression baseline
# Accuracy : 0.7787
# Precision: 0.7794
# Recall   : 0.7535
# F1-score : 0.7662

# %% [markdown]
# ## 8. Neural Network Model (MLP)
#
# Now we train a small multilayer perceptron with two hidden layers. For beginners, the aim is to understand the training loop and validation behavior, not to maximize benchmark numbers. We use `binary_crossentropy` because this is a binary target and add metrics (`accuracy`, `precision`, `recall`, `AUC`) so you can inspect trade-offs.
#
# Early stopping is enabled to prevent over-training once validation loss stops improving. This is a practical regularization pattern you will use often in real workflows.
#
# References for model mechanics: [Keras Sequential API](https://keras.io/guides/sequential_model/), [Keras EarlyStopping](https://keras.io/api/callbacks/early_stopping/), [Adam optimizer paper](https://arxiv.org/abs/1412.6980).

# %%
model = keras.Sequential([
    keras.layers.Input(shape=(X_train.shape[1],)),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(1, activation="sigmoid"),
])

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    loss="binary_crossentropy",
    metrics=[
        keras.metrics.BinaryAccuracy(name="accuracy"),
        keras.metrics.Precision(name="precision"),
        keras.metrics.Recall(name="recall"),
        keras.metrics.AUC(name="auc"),
    ],
)

early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=16,
    restore_best_weights=True,
)

history = model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=512,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1,
)

print(f"Training finished after {len(history.history['loss'])} epochs.")
# Out:
# Epoch 1/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5364 - auc: 0.5521 - loss: 0.7011 - precision: 0.5245 - recall: 0.3976 - val_accuracy: 0.5893 - val_auc: 0.6105 - val_loss: 0.6736 - val_precision: 0.5779 - val_recall: 0.5443
# Epoch 2/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - accuracy: 0.6010 - auc: 0.6448 - loss: 0.6591 - precision: 0.5851 - recall: 0.5884 - val_accuracy: 0.6353 - val_auc: 0.6889 - val_loss: 0.6399 - val_precision: 0.6144 - val_recall: 0.6510
# Epoch 3/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - accuracy: 0.6543 - auc: 0.7150 - loss: 0.6265 - precision: 0.6314 - recall: 0.6772 - val_accuracy: 0.6827 - val_auc: 0.7427 - val_loss: 0.6096 - val_precision: 0.6565 - val_recall: 0.7147
# Epoch 4/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - accuracy: 0.6866 - auc: 0.7619 - loss: 0.5961 - precision: 0.6627 - recall: 0.7107 - val_accuracy: 0.7053 - val_auc: 0.7794 - val_loss: 0.5808 - val_precision: 0.6768 - val_recall: 0.7424
# Epoch 5/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - accuracy: 0.7103 - auc: 0.7926 - loss: 0.5676 - precision: 0.6890 - recall: 0.7258 - val_accuracy: 0.7233 - val_auc: 0.8040 - val_loss: 0.5538 - val_precision: 0.6991 - val_recall: 0.7465
# Epoch 6/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - accuracy: 0.7324 - auc: 0.8136 - loss: 0.5417 - precision: 0.7151 - recall: 0.7383 - val_accuracy: 0.7420 - val_auc: 0.8211 - val_loss: 0.5303 - val_precision: 0.7195 - val_recall: 0.7604
# Epoch 7/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.7459 - auc: 0.8282 - loss: 0.5202 - precision: 0.7305 - recall: 0.7481 - val_accuracy: 0.7527 - val_auc: 0.8333 - val_loss: 0.5111 - val_precision: 0.7337 - val_recall: 0.7632
# Epoch 8/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - accuracy: 0.7563 - auc: 0.8386 - loss: 0.5031 - precision: 0.7436 - recall: 0.7537 - val_accuracy: 0.7587 - val_auc: 0.8426 - val_loss: 0.4960 - val_precision: 0.7413 - val_recall: 0.7659
# Epoch 9/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - accuracy: 0.7644 - auc: 0.8463 - loss: 0.4899 - precision: 0.7532 - recall: 0.7596 - val_accuracy: 0.7640 - val_auc: 0.8487 - val_loss: 0.4846 - val_precision: 0.7466 - val_recall: 0.7715
# Epoch 10/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - accuracy: 0.7693 - auc: 0.8520 - loss: 0.4799 - precision: 0.7582 - recall: 0.7647 - val_accuracy: 0.7720 - val_auc: 0.8536 - val_loss: 0.4758 - val_precision: 0.7561 - val_recall: 0.7770
# Epoch 11/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.7721 - auc: 0.8564 - loss: 0.4722 - precision: 0.7625 - recall: 0.7650 - val_accuracy: 0.7780 - val_auc: 0.8578 - val_loss: 0.4691 - val_precision: 0.7632 - val_recall: 0.7812
# Epoch 12/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - accuracy: 0.7761 - auc: 0.8601 - loss: 0.4659 - precision: 0.7670 - recall: 0.7685 - val_accuracy: 0.7773 - val_auc: 0.8607 - val_loss: 0.4638 - val_precision: 0.7643 - val_recall: 0.7770
# Epoch 13/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - accuracy: 0.7803 - auc: 0.8632 - loss: 0.4607 - precision: 0.7718 - recall: 0.7718 - val_accuracy: 0.7767 - val_auc: 0.8634 - val_loss: 0.4594 - val_precision: 0.7633 - val_recall: 0.7770
# Epoch 14/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - accuracy: 0.7824 - auc: 0.8660 - loss: 0.4562 - precision: 0.7743 - recall: 0.7736 - val_accuracy: 0.7813 - val_auc: 0.8656 - val_loss: 0.4557 - val_precision: 0.7706 - val_recall: 0.7770
# Epoch 15/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.7851 - auc: 0.8685 - loss: 0.4521 - precision: 0.7762 - recall: 0.7780 - val_accuracy: 0.7833 - val_auc: 0.8676 - val_loss: 0.4524 - val_precision: 0.7738 - val_recall: 0.7770
# Epoch 16/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - accuracy: 0.7864 - auc: 0.8709 - loss: 0.4484 - precision: 0.7774 - recall: 0.7795 - val_accuracy: 0.7873 - val_auc: 0.8696 - val_loss: 0.4494 - val_precision: 0.7779 - val_recall: 0.7812
# Epoch 17/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - accuracy: 0.7884 - auc: 0.8731 - loss: 0.4449 - precision: 0.7807 - recall: 0.7795 - val_accuracy: 0.7900 - val_auc: 0.8713 - val_loss: 0.4466 - val_precision: 0.7815 - val_recall: 0.7825
# Epoch 18/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - accuracy: 0.7901 - auc: 0.8752 - loss: 0.4414 - precision: 0.7825 - recall: 0.7813 - val_accuracy: 0.7933 - val_auc: 0.8729 - val_loss: 0.4439 - val_precision: 0.7853 - val_recall: 0.7853
# Epoch 19/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.7904 - auc: 0.8772 - loss: 0.4381 - precision: 0.7821 - recall: 0.7828 - val_accuracy: 0.7940 - val_auc: 0.8744 - val_loss: 0.4413 - val_precision: 0.7848 - val_recall: 0.7881
# Epoch 20/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.7944 - auc: 0.8792 - loss: 0.4349 - precision: 0.7871 - recall: 0.7855 - val_accuracy: 0.7947 - val_auc: 0.8761 - val_loss: 0.4387 - val_precision: 0.7851 - val_recall: 0.7895
# Epoch 21/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - accuracy: 0.7959 - auc: 0.8811 - loss: 0.4318 - precision: 0.7888 - recall: 0.7866 - val_accuracy: 0.7947 - val_auc: 0.8777 - val_loss: 0.4362 - val_precision: 0.7859 - val_recall: 0.7881
# Epoch 22/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - accuracy: 0.7984 - auc: 0.8830 - loss: 0.4287 - precision: 0.7916 - recall: 0.7890 - val_accuracy: 0.7933 - val_auc: 0.8792 - val_loss: 0.4336 - val_precision: 0.7845 - val_recall: 0.7867
# Epoch 23/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - accuracy: 0.7994 - auc: 0.8848 - loss: 0.4256 - precision: 0.7929 - recall: 0.7896 - val_accuracy: 0.7953 - val_auc: 0.8809 - val_loss: 0.4311 - val_precision: 0.7878 - val_recall: 0.7867
# Epoch 24/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.8024 - auc: 0.8866 - loss: 0.4225 - precision: 0.7961 - recall: 0.7926 - val_accuracy: 0.7960 - val_auc: 0.8824 - val_loss: 0.4286 - val_precision: 0.7881 - val_recall: 0.7881
# Epoch 25/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step - accuracy: 0.8041 - auc: 0.8884 - loss: 0.4194 - precision: 0.7983 - recall: 0.7938 - val_accuracy: 0.7987 - val_auc: 0.8839 - val_loss: 0.4260 - val_precision: 0.7909 - val_recall: 0.7909
# Epoch 26/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - accuracy: 0.8051 - auc: 0.8903 - loss: 0.4163 - precision: 0.7992 - recall: 0.7950 - val_accuracy: 0.8000 - val_auc: 0.8853 - val_loss: 0.4235 - val_precision: 0.7914 - val_recall: 0.7936
# Epoch 27/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.8066 - auc: 0.8921 - loss: 0.4132 - precision: 0.8009 - recall: 0.7961 - val_accuracy: 0.8007 - val_auc: 0.8867 - val_loss: 0.4210 - val_precision: 0.7909 - val_recall: 0.7964
# Epoch 28/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - accuracy: 0.8090 - auc: 0.8939 - loss: 0.4101 - precision: 0.8044 - recall: 0.7970 - val_accuracy: 0.8020 - val_auc: 0.8883 - val_loss: 0.4184 - val_precision: 0.7923 - val_recall: 0.7978
# Epoch 29/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - accuracy: 0.8124 - auc: 0.8957 - loss: 0.4070 - precision: 0.8082 - recall: 0.8003 - val_accuracy: 0.8007 - val_auc: 0.8898 - val_loss: 0.4159 - val_precision: 0.7925 - val_recall: 0.7936
# Epoch 30/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.8139 - auc: 0.8975 - loss: 0.4038 - precision: 0.8090 - recall: 0.8030 - val_accuracy: 0.8020 - val_auc: 0.8913 - val_loss: 0.4133 - val_precision: 0.7947 - val_recall: 0.7936
# Epoch 31/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - accuracy: 0.8157 - auc: 0.8992 - loss: 0.4006 - precision: 0.8119 - recall: 0.8033 - val_accuracy: 0.8047 - val_auc: 0.8928 - val_loss: 0.4107 - val_precision: 0.7975 - val_recall: 0.7964
# Epoch 32/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.8177 - auc: 0.9010 - loss: 0.3975 - precision: 0.8137 - recall: 0.8059 - val_accuracy: 0.8080 - val_auc: 0.8943 - val_loss: 0.4082 - val_precision: 0.7997 - val_recall: 0.8019
# Epoch 33/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - accuracy: 0.8189 - auc: 0.9028 - loss: 0.3943 - precision: 0.8145 - recall: 0.8077 - val_accuracy: 0.8093 - val_auc: 0.8958 - val_loss: 0.4055 - val_precision: 0.8011 - val_recall: 0.8033
# Epoch 34/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.8201 - auc: 0.9045 - loss: 0.3912 - precision: 0.8159 - recall: 0.8089 - val_accuracy: 0.8093 - val_auc: 0.8974 - val_loss: 0.4028 - val_precision: 0.8003 - val_recall: 0.8047
# Epoch 35/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step - accuracy: 0.8231 - auc: 0.9062 - loss: 0.3880 - precision: 0.8182 - recall: 0.8134 - val_accuracy: 0.8147 - val_auc: 0.8988 - val_loss: 0.4001 - val_precision: 0.8066 - val_recall: 0.8089
# Epoch 36/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.8239 - auc: 0.9079 - loss: 0.3848 - precision: 0.8191 - recall: 0.8139 - val_accuracy: 0.8167 - val_auc: 0.9004 - val_loss: 0.3975 - val_precision: 0.8074 - val_recall: 0.8130
# Epoch 37/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.8250 - auc: 0.9095 - loss: 0.3817 - precision: 0.8202 - recall: 0.8151 - val_accuracy: 0.8187 - val_auc: 0.9018 - val_loss: 0.3949 - val_precision: 0.8091 - val_recall: 0.8158
# Epoch 38/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.8261 - auc: 0.9112 - loss: 0.3785 - precision: 0.8212 - recall: 0.8166 - val_accuracy: 0.8207 - val_auc: 0.9031 - val_loss: 0.3923 - val_precision: 0.8098 - val_recall: 0.8199
# Epoch 39/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.8281 - auc: 0.9128 - loss: 0.3754 - precision: 0.8237 - recall: 0.8181 - val_accuracy: 0.8213 - val_auc: 0.9046 - val_loss: 0.3897 - val_precision: 0.8084 - val_recall: 0.8241
# Epoch 40/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.8311 - auc: 0.9143 - loss: 0.3722 - precision: 0.8260 - recall: 0.8226 - val_accuracy: 0.8233 - val_auc: 0.9060 - val_loss: 0.3871 - val_precision: 0.8134 - val_recall: 0.8213
# Epoch 41/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - accuracy: 0.8330 - auc: 0.9159 - loss: 0.3692 - precision: 0.8274 - recall: 0.8252 - val_accuracy: 0.8253 - val_auc: 0.9075 - val_loss: 0.3844 - val_precision: 0.8168 - val_recall: 0.8213
# Epoch 42/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.8351 - auc: 0.9174 - loss: 0.3661 - precision: 0.8296 - recall: 0.8276 - val_accuracy: 0.8267 - val_auc: 0.9089 - val_loss: 0.3818 - val_precision: 0.8182 - val_recall: 0.8227
# Epoch 43/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.8364 - auc: 0.9189 - loss: 0.3631 - precision: 0.8310 - recall: 0.8288 - val_accuracy: 0.8280 - val_auc: 0.9102 - val_loss: 0.3792 - val_precision: 0.8196 - val_recall: 0.8241
# Epoch 44/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.8389 - auc: 0.9203 - loss: 0.3602 - precision: 0.8330 - recall: 0.8320 - val_accuracy: 0.8300 - val_auc: 0.9115 - val_loss: 0.3767 - val_precision: 0.8212 - val_recall: 0.8269
# Epoch 45/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - accuracy: 0.8401 - auc: 0.9217 - loss: 0.3573 - precision: 0.8347 - recall: 0.8329 - val_accuracy: 0.8327 - val_auc: 0.9127 - val_loss: 0.3742 - val_precision: 0.8239 - val_recall: 0.8296
# Epoch 46/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.8420 - auc: 0.9231 - loss: 0.3544 - precision: 0.8363 - recall: 0.8353 - val_accuracy: 0.8327 - val_auc: 0.9139 - val_loss: 0.3719 - val_precision: 0.8239 - val_recall: 0.8296
# Epoch 47/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - accuracy: 0.8427 - auc: 0.9244 - loss: 0.3516 - precision: 0.8369 - recall: 0.8362 - val_accuracy: 0.8333 - val_auc: 0.9153 - val_loss: 0.3695 - val_precision: 0.8242 - val_recall: 0.8310
# Epoch 48/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - accuracy: 0.8427 - auc: 0.9257 - loss: 0.3487 - precision: 0.8361 - recall: 0.8374 - val_accuracy: 0.8347 - val_auc: 0.9163 - val_loss: 0.3672 - val_precision: 0.8247 - val_recall: 0.8338
# Epoch 49/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.8439 - auc: 0.9270 - loss: 0.3459 - precision: 0.8367 - recall: 0.8395 - val_accuracy: 0.8360 - val_auc: 0.9175 - val_loss: 0.3649 - val_precision: 0.8251 - val_recall: 0.8366
# Epoch 50/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.8451 - auc: 0.9282 - loss: 0.3432 - precision: 0.8378 - recall: 0.8412 - val_accuracy: 0.8380 - val_auc: 0.9185 - val_loss: 0.3627 - val_precision: 0.8259 - val_recall: 0.8407
# Epoch 51/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.8461 - auc: 0.9294 - loss: 0.3406 - precision: 0.8389 - recall: 0.8421 - val_accuracy: 0.8380 - val_auc: 0.9196 - val_loss: 0.3606 - val_precision: 0.8259 - val_recall: 0.8407
# Epoch 52/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - accuracy: 0.8476 - auc: 0.9306 - loss: 0.3379 - precision: 0.8402 - recall: 0.8439 - val_accuracy: 0.8393 - val_auc: 0.9206 - val_loss: 0.3585 - val_precision: 0.8263 - val_recall: 0.8435
# Epoch 53/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.8494 - auc: 0.9317 - loss: 0.3354 - precision: 0.8420 - recall: 0.8460 - val_accuracy: 0.8407 - val_auc: 0.9216 - val_loss: 0.3565 - val_precision: 0.8277 - val_recall: 0.8449
# Epoch 54/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step - accuracy: 0.8510 - auc: 0.9328 - loss: 0.3328 - precision: 0.8439 - recall: 0.8472 - val_accuracy: 0.8433 - val_auc: 0.9224 - val_loss: 0.3545 - val_precision: 0.8304 - val_recall: 0.8476
# Epoch 55/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - accuracy: 0.8514 - auc: 0.9339 - loss: 0.3304 - precision: 0.8447 - recall: 0.8472 - val_accuracy: 0.8453 - val_auc: 0.9233 - val_loss: 0.3526 - val_precision: 0.8320 - val_recall: 0.8504
# Epoch 56/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step - accuracy: 0.8524 - auc: 0.9349 - loss: 0.3279 - precision: 0.8462 - recall: 0.8475 - val_accuracy: 0.8480 - val_auc: 0.9241 - val_loss: 0.3508 - val_precision: 0.8347 - val_recall: 0.8532
# Epoch 57/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - accuracy: 0.8530 - auc: 0.9360 - loss: 0.3256 - precision: 0.8470 - recall: 0.8478 - val_accuracy: 0.8480 - val_auc: 0.9249 - val_loss: 0.3491 - val_precision: 0.8347 - val_recall: 0.8532
# Epoch 58/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.8543 - auc: 0.9369 - loss: 0.3232 - precision: 0.8485 - recall: 0.8490 - val_accuracy: 0.8500 - val_auc: 0.9256 - val_loss: 0.3474 - val_precision: 0.8390 - val_recall: 0.8518
# Epoch 59/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.8547 - auc: 0.9379 - loss: 0.3210 - precision: 0.8490 - recall: 0.8493 - val_accuracy: 0.8487 - val_auc: 0.9264 - val_loss: 0.3459 - val_precision: 0.8377 - val_recall: 0.8504
# Epoch 60/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 0.8564 - auc: 0.9388 - loss: 0.3188 - precision: 0.8510 - recall: 0.8507 - val_accuracy: 0.8507 - val_auc: 0.9270 - val_loss: 0.3444 - val_precision: 0.8411 - val_recall: 0.8504
# Epoch 61/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - accuracy: 0.8567 - auc: 0.9396 - loss: 0.3166 - precision: 0.8517 - recall: 0.8504 - val_accuracy: 0.8527 - val_auc: 0.9276 - val_loss: 0.3429 - val_precision: 0.8436 - val_recall: 0.8518
# Epoch 62/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - accuracy: 0.8574 - auc: 0.9404 - loss: 0.3145 - precision: 0.8523 - recall: 0.8513 - val_accuracy: 0.8520 - val_auc: 0.9282 - val_loss: 0.3416 - val_precision: 0.8444 - val_recall: 0.8490
# Epoch 63/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - accuracy: 0.8584 - auc: 0.9412 - loss: 0.3125 - precision: 0.8535 - recall: 0.8522 - val_accuracy: 0.8527 - val_auc: 0.9288 - val_loss: 0.3402 - val_precision: 0.8436 - val_recall: 0.8518
# Epoch 64/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - accuracy: 0.8597 - auc: 0.9420 - loss: 0.3105 - precision: 0.8543 - recall: 0.8543 - val_accuracy: 0.8547 - val_auc: 0.9295 - val_loss: 0.3389 - val_precision: 0.8462 - val_recall: 0.8532
# Epoch 65/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - accuracy: 0.8609 - auc: 0.9427 - loss: 0.3086 - precision: 0.8563 - recall: 0.8543 - val_accuracy: 0.8560 - val_auc: 0.9299 - val_loss: 0.3377 - val_precision: 0.8485 - val_recall: 0.8532
# Epoch 66/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.8604 - auc: 0.9434 - loss: 0.3068 - precision: 0.8564 - recall: 0.8531 - val_accuracy: 0.8560 - val_auc: 0.9305 - val_loss: 0.3365 - val_precision: 0.8485 - val_recall: 0.8532
# Epoch 67/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.8611 - auc: 0.9441 - loss: 0.3049 - precision: 0.8571 - recall: 0.8540 - val_accuracy: 0.8547 - val_auc: 0.9308 - val_loss: 0.3354 - val_precision: 0.8462 - val_recall: 0.8532
# Epoch 68/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step - accuracy: 0.8613 - auc: 0.9447 - loss: 0.3031 - precision: 0.8573 - recall: 0.8540 - val_accuracy: 0.8547 - val_auc: 0.9313 - val_loss: 0.3343 - val_precision: 0.8452 - val_recall: 0.8546
# Epoch 69/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - accuracy: 0.8611 - auc: 0.9454 - loss: 0.3014 - precision: 0.8568 - recall: 0.8543 - val_accuracy: 0.8553 - val_auc: 0.9317 - val_loss: 0.3333 - val_precision: 0.8454 - val_recall: 0.8560
# Epoch 70/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step - accuracy: 0.8613 - auc: 0.9460 - loss: 0.2997 - precision: 0.8560 - recall: 0.8558 - val_accuracy: 0.8573 - val_auc: 0.9321 - val_loss: 0.3323 - val_precision: 0.8470 - val_recall: 0.8587
# Epoch 71/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - accuracy: 0.8626 - auc: 0.9467 - loss: 0.2980 - precision: 0.8577 - recall: 0.8567 - val_accuracy: 0.8560 - val_auc: 0.9325 - val_loss: 0.3313 - val_precision: 0.8456 - val_recall: 0.8573
# Epoch 72/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step - accuracy: 0.8641 - auc: 0.9473 - loss: 0.2963 - precision: 0.8586 - recall: 0.8593 - val_accuracy: 0.8560 - val_auc: 0.9329 - val_loss: 0.3304 - val_precision: 0.8456 - val_recall: 0.8573
# Epoch 73/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - accuracy: 0.8643 - auc: 0.9478 - loss: 0.2948 - precision: 0.8593 - recall: 0.8588 - val_accuracy: 0.8580 - val_auc: 0.9331 - val_loss: 0.3296 - val_precision: 0.8482 - val_recall: 0.8587
# Epoch 74/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - accuracy: 0.8650 - auc: 0.9484 - loss: 0.2932 - precision: 0.8597 - recall: 0.8599 - val_accuracy: 0.8587 - val_auc: 0.9335 - val_loss: 0.3288 - val_precision: 0.8493 - val_recall: 0.8587
# Epoch 75/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - accuracy: 0.8659 - auc: 0.9489 - loss: 0.2917 - precision: 0.8606 - recall: 0.8608 - val_accuracy: 0.8593 - val_auc: 0.9338 - val_loss: 0.3280 - val_precision: 0.8495 - val_recall: 0.8601
# Epoch 76/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.8667 - auc: 0.9494 - loss: 0.2903 - precision: 0.8615 - recall: 0.8617 - val_accuracy: 0.8607 - val_auc: 0.9341 - val_loss: 0.3273 - val_precision: 0.8519 - val_recall: 0.8601
# Epoch 77/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.8684 - auc: 0.9499 - loss: 0.2889 - precision: 0.8626 - recall: 0.8644 - val_accuracy: 0.8593 - val_auc: 0.9344 - val_loss: 0.3266 - val_precision: 0.8514 - val_recall: 0.8573
# Epoch 78/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - accuracy: 0.8689 - auc: 0.9503 - loss: 0.2875 - precision: 0.8634 - recall: 0.8644 - val_accuracy: 0.8593 - val_auc: 0.9346 - val_loss: 0.3260 - val_precision: 0.8514 - val_recall: 0.8573
# Epoch 79/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.8699 - auc: 0.9508 - loss: 0.2862 - precision: 0.8641 - recall: 0.8659 - val_accuracy: 0.8587 - val_auc: 0.9349 - val_loss: 0.3254 - val_precision: 0.8503 - val_recall: 0.8573
# Epoch 80/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.8704 - auc: 0.9512 - loss: 0.2848 - precision: 0.8651 - recall: 0.8659 - val_accuracy: 0.8587 - val_auc: 0.9351 - val_loss: 0.3248 - val_precision: 0.8503 - val_recall: 0.8573
# Epoch 81/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - accuracy: 0.8704 - auc: 0.9517 - loss: 0.2836 - precision: 0.8653 - recall: 0.8656 - val_accuracy: 0.8593 - val_auc: 0.9352 - val_loss: 0.3241 - val_precision: 0.8505 - val_recall: 0.8587
# Epoch 82/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 0.8711 - auc: 0.9522 - loss: 0.2823 - precision: 0.8662 - recall: 0.8662 - val_accuracy: 0.8600 - val_auc: 0.9355 - val_loss: 0.3236 - val_precision: 0.8507 - val_recall: 0.8601
# Epoch 83/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - accuracy: 0.8723 - auc: 0.9526 - loss: 0.2811 - precision: 0.8674 - recall: 0.8674 - val_accuracy: 0.8607 - val_auc: 0.9358 - val_loss: 0.3230 - val_precision: 0.8509 - val_recall: 0.8615
# Epoch 84/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - accuracy: 0.8729 - auc: 0.9530 - loss: 0.2799 - precision: 0.8684 - recall: 0.8674 - val_accuracy: 0.8613 - val_auc: 0.9359 - val_loss: 0.3225 - val_precision: 0.8511 - val_recall: 0.8629
# Epoch 85/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - accuracy: 0.8743 - auc: 0.9534 - loss: 0.2787 - precision: 0.8703 - recall: 0.8682 - val_accuracy: 0.8613 - val_auc: 0.9362 - val_loss: 0.3220 - val_precision: 0.8511 - val_recall: 0.8629
# Epoch 86/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - accuracy: 0.8749 - auc: 0.9538 - loss: 0.2775 - precision: 0.8709 - recall: 0.8688 - val_accuracy: 0.8620 - val_auc: 0.9365 - val_loss: 0.3215 - val_precision: 0.8513 - val_recall: 0.8643
# Epoch 87/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - accuracy: 0.8760 - auc: 0.9541 - loss: 0.2764 - precision: 0.8719 - recall: 0.8703 - val_accuracy: 0.8613 - val_auc: 0.9366 - val_loss: 0.3210 - val_precision: 0.8511 - val_recall: 0.8629
# Epoch 88/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - accuracy: 0.8764 - auc: 0.9545 - loss: 0.2753 - precision: 0.8716 - recall: 0.8718 - val_accuracy: 0.8600 - val_auc: 0.9368 - val_loss: 0.3205 - val_precision: 0.8488 - val_recall: 0.8629
# Epoch 89/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - accuracy: 0.8780 - auc: 0.9549 - loss: 0.2742 - precision: 0.8733 - recall: 0.8733 - val_accuracy: 0.8613 - val_auc: 0.9371 - val_loss: 0.3201 - val_precision: 0.8501 - val_recall: 0.8643
# Epoch 90/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.8794 - auc: 0.9552 - loss: 0.2731 - precision: 0.8748 - recall: 0.8748 - val_accuracy: 0.8607 - val_auc: 0.9372 - val_loss: 0.3196 - val_precision: 0.8509 - val_recall: 0.8615
# Epoch 91/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - accuracy: 0.8804 - auc: 0.9556 - loss: 0.2720 - precision: 0.8759 - recall: 0.8757 - val_accuracy: 0.8620 - val_auc: 0.9374 - val_loss: 0.3192 - val_precision: 0.8523 - val_recall: 0.8629
# Epoch 92/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - accuracy: 0.8821 - auc: 0.9560 - loss: 0.2710 - precision: 0.8775 - recall: 0.8777 - val_accuracy: 0.8620 - val_auc: 0.9375 - val_loss: 0.3188 - val_precision: 0.8523 - val_recall: 0.8629
# Epoch 93/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - accuracy: 0.8824 - auc: 0.9563 - loss: 0.2700 - precision: 0.8773 - recall: 0.8786 - val_accuracy: 0.8633 - val_auc: 0.9377 - val_loss: 0.3183 - val_precision: 0.8536 - val_recall: 0.8643
# Epoch 94/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 0.8831 - auc: 0.9566 - loss: 0.2690 - precision: 0.8782 - recall: 0.8792 - val_accuracy: 0.8633 - val_auc: 0.9379 - val_loss: 0.3179 - val_precision: 0.8546 - val_recall: 0.8629
# Epoch 95/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 0.8836 - auc: 0.9569 - loss: 0.2680 - precision: 0.8785 - recall: 0.8798 - val_accuracy: 0.8640 - val_auc: 0.9382 - val_loss: 0.3175 - val_precision: 0.8558 - val_recall: 0.8629
# Epoch 96/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.8843 - auc: 0.9573 - loss: 0.2670 - precision: 0.8794 - recall: 0.8804 - val_accuracy: 0.8633 - val_auc: 0.9383 - val_loss: 0.3171 - val_precision: 0.8546 - val_recall: 0.8629
# Epoch 97/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - accuracy: 0.8847 - auc: 0.9576 - loss: 0.2661 - precision: 0.8795 - recall: 0.8813 - val_accuracy: 0.8640 - val_auc: 0.9385 - val_loss: 0.3168 - val_precision: 0.8558 - val_recall: 0.8629
# Epoch 98/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.8856 - auc: 0.9579 - loss: 0.2651 - precision: 0.8804 - recall: 0.8822 - val_accuracy: 0.8640 - val_auc: 0.9386 - val_loss: 0.3164 - val_precision: 0.8558 - val_recall: 0.8629
# Epoch 99/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step - accuracy: 0.8860 - auc: 0.9582 - loss: 0.2642 - precision: 0.8807 - recall: 0.8828 - val_accuracy: 0.8640 - val_auc: 0.9388 - val_loss: 0.3161 - val_precision: 0.8558 - val_recall: 0.8629
# Epoch 100/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - accuracy: 0.8860 - auc: 0.9585 - loss: 0.2633 - precision: 0.8809 - recall: 0.8825 - val_accuracy: 0.8640 - val_auc: 0.9389 - val_loss: 0.3158 - val_precision: 0.8558 - val_recall: 0.8629
# Epoch 101/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.8860 - auc: 0.9587 - loss: 0.2624 - precision: 0.8809 - recall: 0.8825 - val_accuracy: 0.8633 - val_auc: 0.9389 - val_loss: 0.3155 - val_precision: 0.8556 - val_recall: 0.8615
# Epoch 102/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.8866 - auc: 0.9590 - loss: 0.2615 - precision: 0.8815 - recall: 0.8831 - val_accuracy: 0.8627 - val_auc: 0.9391 - val_loss: 0.3152 - val_precision: 0.8544 - val_recall: 0.8615
# Epoch 103/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.8871 - auc: 0.9593 - loss: 0.2606 - precision: 0.8819 - recall: 0.8840 - val_accuracy: 0.8627 - val_auc: 0.9392 - val_loss: 0.3150 - val_precision: 0.8544 - val_recall: 0.8615
# Epoch 104/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.8871 - auc: 0.9596 - loss: 0.2597 - precision: 0.8812 - recall: 0.8849 - val_accuracy: 0.8640 - val_auc: 0.9393 - val_loss: 0.3147 - val_precision: 0.8567 - val_recall: 0.8615
# Epoch 105/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.8874 - auc: 0.9599 - loss: 0.2589 - precision: 0.8815 - recall: 0.8852 - val_accuracy: 0.8647 - val_auc: 0.9395 - val_loss: 0.3144 - val_precision: 0.8579 - val_recall: 0.8615
# Epoch 106/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - accuracy: 0.8876 - auc: 0.9601 - loss: 0.2580 - precision: 0.8820 - recall: 0.8849 - val_accuracy: 0.8653 - val_auc: 0.9396 - val_loss: 0.3142 - val_precision: 0.8591 - val_recall: 0.8615
# Epoch 107/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - accuracy: 0.8877 - auc: 0.9604 - loss: 0.2572 - precision: 0.8820 - recall: 0.8852 - val_accuracy: 0.8660 - val_auc: 0.9396 - val_loss: 0.3140 - val_precision: 0.8593 - val_recall: 0.8629
# Epoch 108/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.8893 - auc: 0.9606 - loss: 0.2564 - precision: 0.8835 - recall: 0.8869 - val_accuracy: 0.8660 - val_auc: 0.9397 - val_loss: 0.3138 - val_precision: 0.8593 - val_recall: 0.8629
# Epoch 109/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - accuracy: 0.8897 - auc: 0.9609 - loss: 0.2556 - precision: 0.8836 - recall: 0.8878 - val_accuracy: 0.8660 - val_auc: 0.9396 - val_loss: 0.3136 - val_precision: 0.8593 - val_recall: 0.8629
# Epoch 110/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - accuracy: 0.8896 - auc: 0.9611 - loss: 0.2548 - precision: 0.8836 - recall: 0.8875 - val_accuracy: 0.8653 - val_auc: 0.9398 - val_loss: 0.3134 - val_precision: 0.8581 - val_recall: 0.8629
# Epoch 111/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 0.8903 - auc: 0.9614 - loss: 0.2540 - precision: 0.8849 - recall: 0.8875 - val_accuracy: 0.8660 - val_auc: 0.9399 - val_loss: 0.3133 - val_precision: 0.8583 - val_recall: 0.8643
# Epoch 112/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - accuracy: 0.8907 - auc: 0.9617 - loss: 0.2532 - precision: 0.8857 - recall: 0.8875 - val_accuracy: 0.8653 - val_auc: 0.9398 - val_loss: 0.3131 - val_precision: 0.8571 - val_recall: 0.8643
# Epoch 113/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - accuracy: 0.8910 - auc: 0.9619 - loss: 0.2524 - precision: 0.8865 - recall: 0.8872 - val_accuracy: 0.8653 - val_auc: 0.9400 - val_loss: 0.3129 - val_precision: 0.8571 - val_recall: 0.8643
# Epoch 114/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - accuracy: 0.8913 - auc: 0.9621 - loss: 0.2516 - precision: 0.8865 - recall: 0.8878 - val_accuracy: 0.8653 - val_auc: 0.9401 - val_loss: 0.3127 - val_precision: 0.8571 - val_recall: 0.8643
# Epoch 115/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - accuracy: 0.8916 - auc: 0.9623 - loss: 0.2508 - precision: 0.8866 - recall: 0.8884 - val_accuracy: 0.8653 - val_auc: 0.9402 - val_loss: 0.3125 - val_precision: 0.8571 - val_recall: 0.8643
# Epoch 116/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.8917 - auc: 0.9626 - loss: 0.2501 - precision: 0.8866 - recall: 0.8887 - val_accuracy: 0.8653 - val_auc: 0.9404 - val_loss: 0.3123 - val_precision: 0.8571 - val_recall: 0.8643
# Epoch 117/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.8921 - auc: 0.9628 - loss: 0.2493 - precision: 0.8874 - recall: 0.8887 - val_accuracy: 0.8653 - val_auc: 0.9404 - val_loss: 0.3122 - val_precision: 0.8562 - val_recall: 0.8657
# Epoch 118/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.8919 - auc: 0.9630 - loss: 0.2486 - precision: 0.8873 - recall: 0.8881 - val_accuracy: 0.8667 - val_auc: 0.9404 - val_loss: 0.3120 - val_precision: 0.8575 - val_recall: 0.8670
# Epoch 119/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.8926 - auc: 0.9632 - loss: 0.2479 - precision: 0.8882 - recall: 0.8887 - val_accuracy: 0.8673 - val_auc: 0.9405 - val_loss: 0.3118 - val_precision: 0.8587 - val_recall: 0.8670
# Epoch 120/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - accuracy: 0.8933 - auc: 0.9634 - loss: 0.2471 - precision: 0.8893 - recall: 0.8890 - val_accuracy: 0.8687 - val_auc: 0.9406 - val_loss: 0.3116 - val_precision: 0.8601 - val_recall: 0.8684
# Epoch 121/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - accuracy: 0.8940 - auc: 0.9637 - loss: 0.2464 - precision: 0.8897 - recall: 0.8902 - val_accuracy: 0.8673 - val_auc: 0.9406 - val_loss: 0.3115 - val_precision: 0.8587 - val_recall: 0.8670
# Epoch 122/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - accuracy: 0.8946 - auc: 0.9638 - loss: 0.2457 - precision: 0.8900 - recall: 0.8911 - val_accuracy: 0.8660 - val_auc: 0.9407 - val_loss: 0.3114 - val_precision: 0.8573 - val_recall: 0.8657
# Epoch 123/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.8943 - auc: 0.9640 - loss: 0.2450 - precision: 0.8897 - recall: 0.8908 - val_accuracy: 0.8667 - val_auc: 0.9408 - val_loss: 0.3113 - val_precision: 0.8585 - val_recall: 0.8657
# Epoch 124/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.8946 - auc: 0.9642 - loss: 0.2444 - precision: 0.8898 - recall: 0.8914 - val_accuracy: 0.8667 - val_auc: 0.9409 - val_loss: 0.3112 - val_precision: 0.8585 - val_recall: 0.8657
# Epoch 125/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.8951 - auc: 0.9644 - loss: 0.2437 - precision: 0.8904 - recall: 0.8920 - val_accuracy: 0.8660 - val_auc: 0.9410 - val_loss: 0.3111 - val_precision: 0.8573 - val_recall: 0.8657
# Epoch 126/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - accuracy: 0.8954 - auc: 0.9646 - loss: 0.2430 - precision: 0.8905 - recall: 0.8926 - val_accuracy: 0.8667 - val_auc: 0.9410 - val_loss: 0.3110 - val_precision: 0.8575 - val_recall: 0.8670
# Epoch 127/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.8961 - auc: 0.9648 - loss: 0.2424 - precision: 0.8916 - recall: 0.8929 - val_accuracy: 0.8667 - val_auc: 0.9411 - val_loss: 0.3110 - val_precision: 0.8575 - val_recall: 0.8670
# Epoch 128/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.8960 - auc: 0.9650 - loss: 0.2417 - precision: 0.8918 - recall: 0.8923 - val_accuracy: 0.8660 - val_auc: 0.9413 - val_loss: 0.3110 - val_precision: 0.8573 - val_recall: 0.8657
# Epoch 129/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 0.8966 - auc: 0.9652 - loss: 0.2411 - precision: 0.8923 - recall: 0.8929 - val_accuracy: 0.8660 - val_auc: 0.9413 - val_loss: 0.3109 - val_precision: 0.8573 - val_recall: 0.8657
# Epoch 130/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.8964 - auc: 0.9654 - loss: 0.2405 - precision: 0.8921 - recall: 0.8929 - val_accuracy: 0.8667 - val_auc: 0.9413 - val_loss: 0.3109 - val_precision: 0.8585 - val_recall: 0.8657
# Epoch 131/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step - accuracy: 0.8966 - auc: 0.9656 - loss: 0.2398 - precision: 0.8921 - recall: 0.8932 - val_accuracy: 0.8660 - val_auc: 0.9413 - val_loss: 0.3108 - val_precision: 0.8573 - val_recall: 0.8657
# Epoch 132/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.8971 - auc: 0.9658 - loss: 0.2392 - precision: 0.8934 - recall: 0.8929 - val_accuracy: 0.8653 - val_auc: 0.9414 - val_loss: 0.3108 - val_precision: 0.8571 - val_recall: 0.8643
# Epoch 133/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - accuracy: 0.8973 - auc: 0.9659 - loss: 0.2386 - precision: 0.8937 - recall: 0.8929 - val_accuracy: 0.8653 - val_auc: 0.9414 - val_loss: 0.3108 - val_precision: 0.8571 - val_recall: 0.8643
# Epoch 134/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.8977 - auc: 0.9661 - loss: 0.2380 - precision: 0.8945 - recall: 0.8929 - val_accuracy: 0.8653 - val_auc: 0.9415 - val_loss: 0.3108 - val_precision: 0.8571 - val_recall: 0.8643
# Epoch 135/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.8977 - auc: 0.9663 - loss: 0.2374 - precision: 0.8945 - recall: 0.8929 - val_accuracy: 0.8647 - val_auc: 0.9415 - val_loss: 0.3108 - val_precision: 0.8560 - val_recall: 0.8643
# Epoch 136/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.8986 - auc: 0.9665 - loss: 0.2369 - precision: 0.8954 - recall: 0.8938 - val_accuracy: 0.8653 - val_auc: 0.9415 - val_loss: 0.3108 - val_precision: 0.8571 - val_recall: 0.8643
# Epoch 137/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 0.8993 - auc: 0.9666 - loss: 0.2363 - precision: 0.8962 - recall: 0.8944 - val_accuracy: 0.8640 - val_auc: 0.9415 - val_loss: 0.3108 - val_precision: 0.8558 - val_recall: 0.8629
# Epoch 138/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 0.8994 - auc: 0.9668 - loss: 0.2357 - precision: 0.8958 - recall: 0.8953 - val_accuracy: 0.8647 - val_auc: 0.9416 - val_loss: 0.3108 - val_precision: 0.8569 - val_recall: 0.8629
# Epoch 139/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - accuracy: 0.9001 - auc: 0.9669 - loss: 0.2352 - precision: 0.8966 - recall: 0.8958 - val_accuracy: 0.8640 - val_auc: 0.9417 - val_loss: 0.3109 - val_precision: 0.8567 - val_recall: 0.8615
# Epoch 140/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.9007 - auc: 0.9671 - loss: 0.2346 - precision: 0.8977 - recall: 0.8958 - val_accuracy: 0.8640 - val_auc: 0.9417 - val_loss: 0.3109 - val_precision: 0.8567 - val_recall: 0.8615
# Epoch 141/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - accuracy: 0.9009 - auc: 0.9673 - loss: 0.2340 - precision: 0.8980 - recall: 0.8958 - val_accuracy: 0.8640 - val_auc: 0.9417 - val_loss: 0.3110 - val_precision: 0.8577 - val_recall: 0.8601
# Epoch 142/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.9014 - auc: 0.9674 - loss: 0.2335 - precision: 0.8983 - recall: 0.8967 - val_accuracy: 0.8633 - val_auc: 0.9417 - val_loss: 0.3110 - val_precision: 0.8566 - val_recall: 0.8601
# Epoch 143/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - accuracy: 0.9017 - auc: 0.9676 - loss: 0.2329 - precision: 0.8984 - recall: 0.8973 - val_accuracy: 0.8633 - val_auc: 0.9416 - val_loss: 0.3111 - val_precision: 0.8566 - val_recall: 0.8601
# Epoch 144/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 0.9020 - auc: 0.9677 - loss: 0.2324 - precision: 0.8989 - recall: 0.8973 - val_accuracy: 0.8640 - val_auc: 0.9417 - val_loss: 0.3111 - val_precision: 0.8577 - val_recall: 0.8601
# Epoch 145/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.9024 - auc: 0.9678 - loss: 0.2319 - precision: 0.8995 - recall: 0.8976 - val_accuracy: 0.8633 - val_auc: 0.9417 - val_loss: 0.3112 - val_precision: 0.8575 - val_recall: 0.8587
# Epoch 146/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - accuracy: 0.9027 - auc: 0.9680 - loss: 0.2314 - precision: 0.8993 - recall: 0.8985 - val_accuracy: 0.8640 - val_auc: 0.9418 - val_loss: 0.3112 - val_precision: 0.8587 - val_recall: 0.8587
# Epoch 147/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - accuracy: 0.9033 - auc: 0.9681 - loss: 0.2308 - precision: 0.8999 - recall: 0.8991 - val_accuracy: 0.8640 - val_auc: 0.9418 - val_loss: 0.3112 - val_precision: 0.8587 - val_recall: 0.8587
# Epoch 148/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - accuracy: 0.9034 - auc: 0.9683 - loss: 0.2303 - precision: 0.9004 - recall: 0.8988 - val_accuracy: 0.8640 - val_auc: 0.9419 - val_loss: 0.3112 - val_precision: 0.8587 - val_recall: 0.8587
# Epoch 149/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - accuracy: 0.9039 - auc: 0.9685 - loss: 0.2298 - precision: 0.9007 - recall: 0.8994 - val_accuracy: 0.8640 - val_auc: 0.9419 - val_loss: 0.3113 - val_precision: 0.8587 - val_recall: 0.8587
# Epoch 150/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - accuracy: 0.9047 - auc: 0.9686 - loss: 0.2293 - precision: 0.9016 - recall: 0.9003 - val_accuracy: 0.8633 - val_auc: 0.9419 - val_loss: 0.3113 - val_precision: 0.8585 - val_recall: 0.8573
# Epoch 151/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step - accuracy: 0.9049 - auc: 0.9687 - loss: 0.2288 - precision: 0.9019 - recall: 0.9003 - val_accuracy: 0.8640 - val_auc: 0.9420 - val_loss: 0.3113 - val_precision: 0.8587 - val_recall: 0.8587
# Epoch 152/512
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - accuracy: 0.9053 - auc: 0.9689 - loss: 0.2283 - precision: 0.9025 - recall: 0.9006 - val_accuracy: 0.8633 - val_auc: 0.9420 - val_loss: 0.3113 - val_precision: 0.8585 - val_recall: 0.8573
# Training finished after 152 epochs.

# %% [markdown]
# ## 9. Training Curves
#
# Training curves help you diagnose model behavior beyond a single metric value. If training loss drops while validation loss rises, you are likely overfitting. If both losses stay high and flat, the model may be underfitting or learning too slowly.
#
# When reading these plots, focus on trend shape rather than one noisy epoch. The ideal pattern is a smooth reduction in both training and validation loss, followed by a plateau where early stopping ends training.

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 4.5))

axes[0].plot(history.history["loss"], label="train_loss")
axes[0].plot(history.history["val_loss"], label="val_loss")
axes[0].set_title("Binary Crossentropy")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Loss")
axes[0].legend()

axes[1].plot(history.history["accuracy"], label="train_accuracy")
axes[1].plot(history.history["val_accuracy"], label="val_accuracy")
axes[1].set_title("Accuracy")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Accuracy")
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Final Evaluation on the Test Set
#
# Only now do we touch the test set. This is your final, unbiased checkpoint after all modeling decisions are complete. We evaluate with multiple metrics because each one captures a different behavior:
#
# - **Accuracy**: the fraction of all predictions that were correct. This is easy to understand, but it can be misleading when classes are imbalanced.
# - **Precision**: among all samples predicted as class `1`, how many were actually class `1`. High precision means fewer false positives.
# - **Recall**: among all true class `1` samples, how many the model successfully found. High recall means fewer false negatives.
# - **F1-score**: the harmonic mean of precision and recall. This is useful when you want a single number that rewards balance between the two.
# - **ROC-AUC**: measures how well the model ranks positive samples above negative ones across many decision thresholds. A value near `1.0` is strong, while `0.5` is roughly random guessing.
#
# The confusion matrix should be read cell-by-cell. Diagonal cells are correct predictions; off-diagonal cells are error types. Your interpretation should connect these errors back to design risk: is predicting “safe” when it is actually “high displacement” more costly than the reverse?
#
# Because this is a structural-response setting, that trade-off matters. If missing a truly high-displacement case is more serious than issuing an occasional false alarm, then **recall** may matter more than **precision**. If false alarms are costly, then precision becomes more important.

# %%
# MLP probabilities and class predictions
mlp_test_proba = model.predict(X_test, verbose=0).ravel()
mlp_test_pred = (mlp_test_proba >= 0.5).astype(int)

# Baseline predictions for direct comparison
baseline_test_pred = baseline.predict(X_test)
baseline_test_proba = baseline.predict_proba(X_test)[:, 1]

print("Test metrics - MLP")
print(f"Accuracy : {accuracy_score(y_test, mlp_test_pred):.4f}")
print(f"Precision: {precision_score(y_test, mlp_test_pred):.4f}")
print(f"Recall   : {recall_score(y_test, mlp_test_pred):.4f}")
print(f"F1-score : {f1_score(y_test, mlp_test_pred):.4f}")
print(f"ROC-AUC  : {roc_auc_score(y_test, mlp_test_proba):.4f}")

print()
print("Test metrics - Logistic Regression baseline")
print(f"Accuracy : {accuracy_score(y_test, baseline_test_pred):.4f}")
print(f"Precision: {precision_score(y_test, baseline_test_pred):.4f}")
print(f"Recall   : {recall_score(y_test, baseline_test_pred):.4f}")
print(f"F1-score : {f1_score(y_test, baseline_test_pred):.4f}")
print(f"ROC-AUC  : {roc_auc_score(y_test, baseline_test_proba):.4f}")

print()
print("Detailed classification report (MLP):")
print(classification_report(y_test, mlp_test_pred, digits=4))

fig, axes = plt.subplots(1, 2, figsize=(13, 5))

ConfusionMatrixDisplay.from_predictions(
    y_test,
    mlp_test_pred,
    cmap="Blues",
    colorbar=False,
    ax=axes[0],
)
axes[0].set_title("MLP Confusion Matrix")

RocCurveDisplay.from_predictions(
    y_test,
    mlp_test_proba,
    ax=axes[1],
)
axes[1].set_title("MLP ROC Curve")

plt.tight_layout()
plt.show()
# Out:
# Test metrics - MLP
# Accuracy : 0.8573
# Precision: 0.8423
# Recall   : 0.8657
# F1-score : 0.8538
# ROC-AUC  : 0.9393
#
# Test metrics - Logistic Regression baseline
# Accuracy : 0.7760
# Precision: 0.7644
# Recall   : 0.7729
# F1-score : 0.7686
# ROC-AUC  : 0.8559
#
# Detailed classification report (MLP):
#               precision    recall  f1-score   support
#
#            0     0.8720    0.8496    0.8607       778
#            1     0.8423    0.8657    0.8538       722
#
#     accuracy                         0.8573      1500
#    macro avg     0.8572    0.8576    0.8573      1500
# weighted avg     0.8577    0.8573    0.8574      1500

# %% [markdown]
# ## 11. Mini Exercises
#
# 1. Change `THRESHOLD` from `10` to `8` and `12`, rerun the notebook, and compare class balance plus metric changes. Explain why the same model architecture can behave differently under these threshold choices.
# 2. Increase the first hidden layer from `64` to `128` units and compare training/validation curves. Did performance improve on test data, or did overfitting increase?
# 3. Replace `StandardScaler` with `MinMaxScaler` and observe whether convergence speed or final metrics change.
# 4. Adjust the classification cutoff from `0.5` to `0.4` for test prediction and discuss how precision-recall trade-offs shift.
